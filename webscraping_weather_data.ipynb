# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import requests
page = requests.get("https://www.timeanddate.com/weather/india/chennai/historic")

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(page.content,"html.parser")

# %%
table=soup.find_all("table",{"class":"zebra tb-wt fw va-m tb-hover"})
l=[]
for i,items in enumerate(table):
    for i,row in enumerate(items.find_all("tr")):
        d = {}
        try:
            d['Temp'] = row.find_all("td",{"class":""})[0].text
        except:
            d['Temp'] = np.nan

        try:
            d['Weather'] = row.find("td",{"class":"small"}).text
        except:
            d['Weather']= np.nan

        try:
            d['Wind'] = row.find_all("td",{"class":"sep"})[0].text
        except:
            d['Wind'] = np.nan

        try:
            d['Direction'] = row.find("span")["title"]
        except:
            try:
                d['Direction'] = row.find("span",{"class":"comp sa16"})["title"]
            except:
                d['Direction'] = np.nan

        try:
            d['Humidity'] = row.find_all("td",{"class":""})[2].text
        except:
            d['Humidity'] = np.nan

        try:
            d['Barometer'] =  row.find_all("td",{"class":"sep"})[1].text
        except:
            d['Barometer'] = np.nan

        try:
            d['Visibility'] =  row.find_all("td",{"class":""})[3].text
        except:
             d['Visibility'] = np.nan

        l.append(d)

# %%
import pandas
df = pandas.DataFrame(l)

# %%
df2 = df.dropna(how = 'all')
df2 = df2.reset_index()
df2.pop('index')
df2['Barometer'] = df2['Barometer'].str.extract('(\d+\.\d+)') + r'"Hg'
df2['Weather'] = df2['Weather'].str.replace(" ","")
df2['Visibility'] = df2['Visibility'].str.extract('(\d+)') + 'mi'
df2['Wind'] = df2['Wind'].str.extract('(\d+)') + 'mph'
df2['Temp'] = df2['Temp'].str.extract('(\d+)') + u'\N{DEGREE SIGN}' + 'F'

# %%
df2.to_csv('data.csv', columns = ['Temp', 'Weather', 'Wind', 'Direction', 'Humidity', 'Barometer',
       'Visibility'])

# %%
df2
# Out:
#     Temp           Weather   Wind  \
# 0   86°F     Partlycloudy.   6mph
# 1   91°F     Brokenclouds.  16mph
# 2   91°F     Brokenclouds.   7mph
# 3   91°F     Brokenclouds.   9mph
# 4   95°F     Brokenclouds.  14mph
# 5   95°F     Brokenclouds.  12mph
# 6   95°F  Scatteredclouds.  12mph
# 7   97°F  Scatteredclouds.  14mph
# 8   97°F  Scatteredclouds.  14mph
# 9   95°F  Scatteredclouds.  14mph
# 10  93°F  Scatteredclouds.   9mph
# 11  93°F  Scatteredclouds.  10mph
# 12  93°F  Scatteredclouds.   8mph
# 13  91°F  Scatteredclouds.   9mph
# 14  90°F  Scatteredclouds.   9mph
# 15  90°F  Scatteredclouds.   9mph
# 16  90°F  Scatteredclouds.   9mph
# 17  88°F  Scatteredclouds.  15mph
# 18  88°F  Scatteredclouds.  15mph
# 19  88°F     Brokenclouds.  12mph
# 20  86°F     Brokenclouds.  12mph
# 21  86°F     Brokenclouds.  12mph
# 22  84°F  Scatteredclouds.   9mph
# 23  84°F  Scatteredclouds.   9mph
# 24  84°F    Passingclouds.  10mph
# 25  86°F    Passingclouds.  10mph
# 26  86°F    Passingclouds.  10mph
# 27  88°F    Passingclouds.  10mph
# 28  88°F    Passingclouds.  10mph
# 29  88°F    Passingclouds.  14mph
# 30  88°F    Passingclouds.  14mph
# 31  88°F    Passingclouds.  14mph
# 32  88°F    Passingclouds.   9mph
# 33  90°F    Passingclouds.   9mph
# 34  90°F    Passingclouds.   9mph
# 35  90°F    Passingclouds.   9mph
# 36  90°F    Passingclouds.   9mph
