# %% [markdown]
# # **Importing Important Libraries**

# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # **Getting the content from the HTML web page**

# %%
import requests
page = requests.get("https://www.timeanddate.com/weather/india/chennai/historic")

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(page.content,"html.parser")

# %% [markdown]
# # **Creating a list of data needed**

# %%
table=soup.find_all("table",{"class":"zebra tb-wt fw va-m tb-hover"})
l=[]
for i,items in enumerate(table):
    for i,row in enumerate(items.find_all("tr")):
        d = {}
        try:
            d['Temp'] = row.find_all("td",{"class":""})[0].text
        except:
            d['Temp'] = np.nan

        try:
            d['Weather'] = row.find("td",{"class":"small"}).text
        except:
            d['Weather']= np.nan

        try:
            d['Wind'] = row.find_all("td",{"class":"sep"})[0].text
        except:
            d['Wind'] = np.nan

        try:
            d['Direction'] = row.find("span")["title"]
        except:
            try:
                d['Direction'] = row.find("span",{"class":"comp sa16"})["title"]
            except:
                d['Direction'] = np.nan

        try:
            d['Humidity'] = row.find_all("td",{"class":""})[2].text
        except:
            d['Humidity'] = np.nan

        try:
            d['Barometer'] =  row.find_all("td",{"class":"sep"})[1].text
        except:
            d['Barometer'] = np.nan

        try:
            d['Visibility'] =  row.find_all("td",{"class":""})[3].text
        except:
             d['Visibility'] = np.nan

        l.append(d)

# %% [markdown]
# # **Converting the list of data to dataframe**

# %%
import pandas
df = pandas.DataFrame(l)

# %%
df2 = df.dropna(how = 'all')
df2 = df2.reset_index()
df2.pop('index')
df2['Barometer'] = df2['Barometer'].str.extract('(\d+\.\d+)') + r'"Hg'
df2['Weather'] = df2['Weather'].str.replace(" ","")
df2['Visibility'] = df2['Visibility'].str.extract('(\d+)') + 'mi'
df2['Wind'] = df2['Wind'].str.extract('(\d+)') + 'mph'
df2['Temp'] = df2['Temp'].str.extract('(\d+)') + u'\N{DEGREE SIGN}' + 'F'

# %% [markdown]
# # **Creating a CSV file of the data**

# %%
df2.to_csv('data.csv', columns = ['Temp', 'Weather', 'Wind', 'Direction', 'Humidity', 'Barometer',
       'Visibility'])

# %%
df2
# Out:
#     Temp           Weather   Wind  \
# 0   31°F     Brokenclouds.  19mph
# 1   31°F     Brokenclouds.  15mph
# 2   30°F     Brokenclouds.  13mph
# 3   30°F     Brokenclouds.  15mph
# 4   29°F     Brokenclouds.  15mph
# 5   29°F              Fog.  13mph
# 6   28°F              Fog.  11mph
# 7   29°F     Partlycloudy.  11mph
# 8   29°F     Partlycloudy.  11mph
# 9   29°F     Partlycloudy.  11mph
# 10  29°F     Partlycloudy.  11mph
# 11  29°F     Partlycloudy.  15mph
# 12  29°F     Partlycloudy.  15mph
# 13  30°F     Partlycloudy.  11mph
# 14  30°F     Partlycloudy.  15mph
# 15  30°F     Partlycloudy.   9mph
# 16  30°F     Partlycloudy.  11mph
# 17  30°F     Partlycloudy.  11mph
# 18  30°F     Partlycloudy.  11mph
# 19  30°F     Partlycloudy.  15mph
# 20  30°F     Partlycloudy.  15mph
# 21  30°F     Partlycloudy.  15mph
# 22  30°F     Partlycloudy.   9mph
# 23  33°F     Brokenclouds.  26mph
# 24  33°F     Brokenclouds.  11mph
# 25  33°F     Brokenclouds.  15mph
# 26  35°F     Brokenclouds.  22mph
# 27  35°F     Brokenclouds.  19mph
# 28  35°F  Scatteredclouds.  19mph
# 29  36°F  Scatteredclouds.  22mph
# 30  36°F  Scatteredclouds.  22mph
# 31  35°F  Scatteredclouds.  22mph
# 32  34°F  Scatteredclouds.  15mph
# 33  34°F  Scatteredclouds.  17mph
# 34  34°F  Scatteredclouds.  13mph
# 35  33°F  Scatteredclouds.  15mph
#
#                                             Direction Humidity Barometer  \
# 0                                                 NaN      66%       NaN
# 1   Wind blowing from 250° West-southwest to East-...      66%       NaN
# 2   Wind blowing from 240° West-southwest to East-...      70%       NaN
# 3                 Wind blowing from 260° West to East      70%       NaN
# 4   Wind blowing from 250° West-southwest to East-...      70%       NaN
# 5   Wind blowing from 250° West-southwest to East-...      70%       NaN
# 6   Wind blowing from 240° West-southwest to East-...      74%       NaN
# 7   Wind blowing from 250° West-southwest to East-...      70%       NaN
# 8   Wind blowing from 250° West-southwest to East-...      70%       NaN
# 9   Wind blowing from 240° West-southwest to East-...      70%       NaN
# 10  Wind blowing from 240° West-southwest to East-...      70%       NaN
# 11                Wind blowing from 260° West to East      70%       NaN
# 12                Wind blowing from 260° West to East      70%       NaN
# 13                Wind blowing from 260° West to East      70%       NaN
# 14                Wind blowing from 280° West to East      70%       NaN
# 15                Wind blowing from 280° West to East      70%       NaN
# 16                                                NaN      75%       NaN
# 17                Wind blowing from 280° West to East      75%       NaN
# 18                Wind blowing from 280° West to East      75%       NaN
# 19                Wind blowing from 280° West to East      70%       NaN
# 20                Wind blowing from 260° West to East      70%       NaN
# 21                Wind blowing from 260° West to East      70%       NaN
# 22      Wind blowing from 220° Southwest to Northeast      75%       NaN
# 23                Wind blowing from 270° West to East      59%       NaN
# 24      Wind blowing from 320° Northwest to Southeast      59%       NaN
# 25      Wind blowing from 320° Northwest to Southeast      59%       NaN
# 26                Wind blowing from 260° West to East      53%       NaN
# 27                Wind blowing from 260° West to East      53%       NaN
# 28                Wind blowing from 270° West to East      50%       NaN
# 29                Wind blowing from 270° West to East      50%       NaN
# 30                Wind blowing from 270° West to East      50%       NaN
# 31                Wind blowing from 270° West to East      53%       NaN
# 32                Wind blowing from 260° West to East      56%       NaN
# 33                Wind blowing from 260° West to East      56%       NaN
# 34  Wind blowing from 250° West-southwest to East-...      56%       NaN
# 35  Wind blowing from 250° West-southwest to East-...      59%       NaN
#
#    Visibility
# 0         5mi
# 1         5mi
# 2         5mi
# 3         5mi
# 4         5mi
# 5         5mi
# 6         5mi
# 7         5mi
# 8         5mi
# 9         5mi
# 10        5mi
# 11        5mi
# 12        5mi
# 13        5mi
# 14        5mi
# 15        5mi
# 16        5mi
# 17        5mi
# 18        5mi
# 19        5mi
# 20        5mi
# 21        5mi
# 22        5mi
# 23        5mi
# 24        5mi
# 25        5mi
# 26        6mi
# 27        6mi
# 28        6mi
# 29        6mi
# 30        6mi
# 31        6mi
# 32        6mi
# 33        6mi
# 34        6mi
# 35        6mi
